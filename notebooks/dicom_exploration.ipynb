# %% [markdown]
# <a href="https://colab.research.google.com/github/ccraig3/ece697-mri-denoising/blob/main/dicom_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !tar -xvf "/content/drive/MyDrive/ECE697/data/knee_mri_dicom_batch2.tar" -C "/content/drive/MyDrive/ECE697/data/share/knee_mri_dicom_batch2/"
# Out:
# Streaming output truncated to the last 5000 lines.
# knee_mri_clinical_seq_batch2/FB_243874____FB,4351887975/study_baef4992/MR6_7e47a074/00018_ca5cb19baaf42533.dcm
# knee_mri_clinical_seq_batch2/FB_243874____FB,4351887975/study_baef4992/MR6_7e47a074/00024_4b0cce74a2e2c895.dcm
# knee_mri_clinical_seq_batch2/FB_243874____FB,4351887975/study_baef4992/MR6_7e47a074/00022_2524aba61928b61e.dcm
# knee_mri_clinical_seq_batch2/FB_243874____FB,4351887975/study_baef4992/MR6_7e47a074/00020_1513bfeaa668a6ab.dcm
# knee_mri_clinical_seq_batch2/FB_243874____FB,4351887975/study_baef4992/MR6_7e47a074/00015_ac1d9ac8b1ad1f96.dcm
# knee_mri_clinical_seq_batch2/FB_243874____FB,4351887975/study_baef4992/MR6_7e47a074/00016_eb84b9b33800e882.dcm
# knee_mri_clinical_seq_batch2/FB_243874____FB,4351887975/study_baef4992/MR6_7e47a074/00005_49f37cbae3c74882.dcm
# knee_mri_clinical_seq_batch2/FB_243874____FB,4351887975/study_baef4992/MR6_7e47a074/00013_ced5716acf672b37.dcm
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install python-gdcm
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 12.8 MB 7.5 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.0 MB 7.4 MB/s
# ...

# %%
import pydicom
import numpy as np

# %%
path = r'/content/drive/MyDrive/Summer 2022/ECE 697/Project/data/1FB_1001820591____1FB,_3331562518/study_2f43b031/MR4_53c76c27/00017_9fd63311562db57c.dcm'

# %%
ds = pydicom.dcmread(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-6cd269ad49e3> in <module>()
# ----> 1 ds = pydicom.dcmread(path)
#
# /usr/local/lib/python3.7/dist-packages/pydicom/filereader.py in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#     991         caller_owns_file = False
#     992         logger.debug("Reading file '{0}'".format(fp))
# --> 993         fp = open(fp, 'rb')
#     994     elif fp is None or not hasattr(fp, "read") or not hasattr(fp, "seek"):
#     995         raise TypeError("dcmread: Expected a file path or a file-like, "
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Summer 2022/ECE 697/Project/data/1FB_1001820591____1FB,_3331562518/study_2f43b031/MR4_53c76c27/00017_9fd63311562db57c.dcm'

# %%
ds.decompress('gdcm')

# %%
data = ds.pixel_array

# %%
data.shape
# Out:
# (384, 384)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.imshow(data, interpolation='nearest', cmap='gray')
plt.axis('off')
plt.show()

# %%
from PIL import Image
from matplotlib import cm
im = Image.fromarray(np.uint8(cm.gray(data/np.max(data))*255))
im.save('outtest.png')
